# %%
import pandas as pd
import pandas as pd
#Add the imports here
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from datetime import datetime
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
from scipy.stats import zscore
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder

# %%
#df.to_csv("shell_company_fraud_smallset.csv", index=False)
df = pd.read_csv('latest_shell_company_fraud_dataset.csv' , encoding='utf-8', low_memory=False)
df.columns = df.columns.str.strip()

# %%
df.head(5)
# Out:
#    LoanNr_ChkDgt                            Name         City State    Zip  \
# 0     1000084002  B&T SCREW MACHINE COMPANY, INC   PLAINVILLE    CT   6062
# 1     1000144007  PROFESSIONAL ELEVATOR SERVICES      CHICAGO    IL  60605
# 2     1000506000             WEYLAND CORPORATION    CAMARILLO    CA  93010
# 3     1000524003     AUDELIA FAMILY DENTAL GROUP       DALLAS    TX  75243
# 4     1000735003              Mykols Marine Inc.  Spring Lake    MI  49417
#
#                             Bank BankState  \
# 0  TD BANK, NATIONAL ASSOCIATION        DE
# 1     BANK OF AMERICA NATL ASSOC        OR
# 2    WELLS FARGO BANK NATL ASSOC        SD
# 3        THE FROST NATIONAL BANK        TX
# 4    WELLS FARGO BANK NATL ASSOC        SD
#
#                                  NAICS ApprovalDate  ApprovalFY  ...  \
# 0                        Manufacturing    2/28/1997        1997  ...
# 1                         Construction    2/28/1997        1997  ...
# 2                 Educational services     2/7/2006        2006  ...
# 3    Health care and social assistance    2/28/1997        1997  ...
# 4  Arts, entertainment, and recreation    3/31/1997        1997  ...
#
#    Late Payment  Annual Revenue     Net income  Credit Score  Taxed_filed  \
# 0             N    1.730830e+06  150539.304000           612          YES
# 1             N    5.417385e+05   27314.406130           601      PENDING
# 2             N    2.636591e+06  131829.564900           497      PENDING
# 3             N    3.595876e+06  179793.796300           547       EXEMPT
# 4             N    1.290236e+05    6451.179845           628       EXEMPT
#
#    Business Licenses Status  Outstanding loans Fraud Trend Over Time  \
# 0                       YES               11.0                Stable
# 1               RENEWAL DUE                8.0                Stable
# 2              NOT REQUIRED                1.0                Stable
# 3               RENEWAL DUE               13.0                Stable
# 4              NOT REQUIRED               10.0                Stable
#
#   fraud_incident                       Purpose_of_credit
# 0              0         Equipment & Technology Upgrades
# 1              0         Equipment & Technology Upgrades
# 2              0  Working Capital & Cash Flow Management
# 3              1         Emergency & Unforeseen Expenses
# 4              0         Equipment & Technology Upgrades
#
# [5 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   LoanNr_ChkDgt              99999 non-null  int64
#  1   Name                       99999 non-null  object
#  2   City                       99999 non-null  object
#  3   State                      99998 non-null  object
#  4   Zip                        99999 non-null  int64
#  5   Bank                       99818 non-null  object
#  6   BankState                  99817 non-null  object
#  7   NAICS                      99999 non-null  object
#  8   ApprovalDate               99999 non-null  object
#  9   ApprovalFY                 99999 non-null  int64
#  10  Term                       99999 non-null  int64
#  11  NoEmp                      99999 non-null  int64
#  12  NewExist                   99963 non-null  float64
#  13  CreateJob                  99999 non-null  int64
#  14  RetainedJob                99999 non-null  int64
#  15  FranchiseCode              99999 non-null  int64
#  16  UrbanRural                 99999 non-null  int64
#  17  RevLineCr                  99735 non-null  object
#  18  LowDoc                     99999 non-null  object
#  19  ChgOffDate                 15591 non-null  object
#  20  DisbursementDate           99724 non-null  object
#  21  DisbursementGross          99999 non-null  int64
#  22  BalanceGross               99999 non-null  int64
#  23  Fraud/Shell company Fraud  99850 non-null  object
#  24  ChgOffPrinGr               99999 non-null  int64
#  25  GrAppv                     99999 non-null  int64
#  26  Sector_Code                99999 non-null  int64
#  27  Loan_backed_Realestate     99999 non-null  object
#  28  NumOfapplications          99999 non-null  int64
#  29  Frequence_of_apps          99999 non-null  object
#  30  payment_consistency        99963 non-null  object
#  31  Credit Utilizations        99999 non-null  object
#  32  Late Payment               99999 non-null  object
#  33  Annual Revenue             99999 non-null  float64
#  34  Net income                 99999 non-null  float64
#  35  Credit Score               99999 non-null  int64
#  36  Taxed_filed                99999 non-null  object
#  37  Business Licenses Status   99999 non-null  object
#  38  Outstanding loans          99877 non-null  float64
#  39  Fraud Trend Over Time      99999 non-null  object
#  40  fraud_incident             99999 non-null  int64
#  41  Purpose_of_credit          99999 non-null  object
# dtypes: float64(4), int64(17), object(21)
# memory usage: 32.0+ MB

# %%
df.describe()
# Out:
#        LoanNr_ChkDgt           Zip    ApprovalFY          Term         NoEmp  \
# count   9.999900e+04  99999.000000  99999.000000  99999.000000  99999.000000
# mean    3.269500e+09  55512.239132   2002.484255    121.334763     30.109151
# std     1.199159e+09  30967.694067      5.989006     85.678133    122.824563
# min     1.000084e+09      0.000000   1984.000000      0.000000     10.000000
# 25%     2.329371e+09  30078.000000   1999.000000     60.000000     12.000000
# 50%     3.271756e+09  56301.000000   2002.000000     84.000000     18.000000
# 75%     4.321649e+09  85012.000000   2007.000000    186.000000     30.000000
# max     5.352774e+09  99999.000000   2012.000000    404.000000   9992.000000
#
#            NewExist     CreateJob   RetainedJob  FranchiseCode    UrbanRural  \
# count  99963.000000  99999.000000  99999.000000   99999.000000  99999.000000
# mean       1.142953      4.577216     15.035440    2672.778428      0.878909
# std        0.353043     28.617292     43.979102   12571.270974      0.606395
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%        1.000000      0.000000      0.000000       0.000000      0.000000
# 50%        1.000000      0.000000     10.000000       1.000000      1.000000
# 75%        1.000000      4.000000     19.000000       1.000000      1.000000
# max        2.000000   5621.000000   9500.000000   91999.000000      2.000000
#
#        ...   BalanceGross  ChgOffPrinGr        GrAppv   Sector_Code  \
# count  ...   99999.000000  9.999900e+04  9.999900e+04  99999.000000
# mean   ...       1.779218  2.321478e+04  3.421559e+05     49.510475
# std    ...     392.627994  1.081466e+05  4.152945e+05     17.915441
# min    ...       0.000000  0.000000e+00  5.000000e+02     11.000000
# 25%    ...       0.000000  0.000000e+00  7.500000e+04     33.000000
# 50%    ...       0.000000  0.000000e+00  1.950000e+05     48.000000
# 75%    ...       0.000000  0.000000e+00  4.500000e+05     62.000000
# max    ...  115820.000000  3.512596e+06  5.472000e+06     92.000000
#
#        NumOfapplications  Annual Revenue    Net income  Credit Score  \
# count       99999.000000    9.999900e+04  9.999900e+04  99999.000000
# mean            4.258063    1.971312e+06  1.133619e+05    587.203882
# std             2.829382    2.515002e+06  1.560776e+05    132.241253
# min             0.000000    0.000000e+00  0.000000e+00    100.000000
# 25%             2.000000    4.496868e+05  2.390046e+04    488.000000
# 50%             3.000000    1.086940e+06  5.898477e+04    593.000000
# 75%             8.000000    2.525467e+06  1.412011e+05    697.000000
# max             9.000000    8.021306e+07  4.010653e+06    800.000000
#
#        Outstanding loans  fraud_incident
# count       99877.000000    99999.000000
# mean           10.072659        0.393524
# std            16.130307        0.488534
# min             1.000000        0.000000
# 25%             4.000000        0.000000
# 50%             7.000000        0.000000
# 75%            10.000000        1.000000
# max           100.000000        1.000000
#
# [8 rows x 21 columns]

# %%
# Lets convert the output/taregt values

# Convert target variable to numeric for correlation
df['Fraud/Shell company Fraud'] = df['Fraud/Shell company Fraud'].map({'P I F': 0, 'CHGOFF': 1})

# %%
#identified Duplicate rows
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [LoanNr_ChkDgt, Name, City, State, Zip, Bank, BankState, NAICS, ApprovalDate, ApprovalFY, Term, NoEmp, NewExist, CreateJob, RetainedJob, FranchiseCode, UrbanRural, RevLineCr, LowDoc, ChgOffDate, DisbursementDate, DisbursementGross, BalanceGross, Fraud/Shell company Fraud, ChgOffPrinGr, GrAppv, Sector_Code, Loan_backed_Realestate, NumOfapplications, Frequence_of_apps, payment_consistency, Credit Utilizations, Late Payment, Annual Revenue, Net income, Credit Score, Taxed_filed, Business Licenses Status, Outstanding loans, Fraud Trend Over Time, fraud_incident, Purpose_of_credit]
# Index: []
#
# [0 rows x 42 columns]

# %%
# Drop non-numeric columns
numerical_cols = df.select_dtypes(include=['int','float']).columns

# Compute correlation matrix
correlation_matrix = df[numerical_cols].corr()

# Extract correlation with Fraud column
fraud_correlation = correlation_matrix["Fraud/Shell company Fraud"].sort_values(ascending=False)
print(fraud_correlation)
# Out:
# Fraud/Shell company Fraud    1.000000
# ChgOffPrinGr                 0.502408
# ApprovalFY                   0.157410
# UrbanRural                   0.109820
# NewExist                     0.061344
# Sector_Code                  0.039491
# RetainedJob                  0.009306
# Credit Score                 0.007498
# fraud_incident               0.001898
# BalanceGross                -0.001929
# Zip                         -0.003512
# FranchiseCode               -0.005663
# NumOfapplications           -0.009650
# CreateJob                   -0.014227
# NoEmp                       -0.019944
# Outstanding loans           -0.031473
# Net income                  -0.098015
# Annual Revenue              -0.103426
# DisbursementGross           -0.110913
# GrAppv                      -0.117327
# LoanNr_ChkDgt               -0.189471
# Term                        -0.296966
# Name: Fraud/Shell company Fraud, dtype: float64

# %%
# Select non-numeric columns 
df_non_numeric = df.select_dtypes(exclude=['int', 'float'])
# Loop through each column and print unique values
for col in df_non_numeric.columns:
    print(f"Unique values in '{col}': {df[col].unique()[:20]} ...")  # Show only first 10 unique values
# Out:
# Unique values in 'Name': ['B&T SCREW MACHINE COMPANY, INC' 'PROFESSIONAL ELEVATOR SERVICES'
#  'WEYLAND CORPORATION' 'AUDELIA FAMILY DENTAL GROUP' 'Mykols Marine Inc.'
#  'ANGEL' 'LABELLE MARIEE, INC.' 'TULON PACIFIC LLC'
#  'WOODLAND PUBLISHING, INC' 'TOUCHPOINTS MARKETING LLC'
#  'Good Earth Produce Inc.' "SPOHN, INC DBA CULVER'S OF MT"
#  'FOOD SOLUTIONS' 'EUROPEAN AUTO CENTER' 'Ferguson Animal Enterprises, I'
#  'R.E. Stegall & Associates Inc.' 'NICHOLS, BROSCH, SANDOVAL & AS'
#  'THE LAGUNITAS BREWING COMPANY' 'Sarni Cleaners of Boston, Inc.'
#  'Crown Coatings LLC'] ...
# Unique values in 'City': ['PLAINVILLE' 'CHICAGO' 'CAMARILLO' 'DALLAS' 'Spring Lake' 'LOS ANGELES'
#  'KIRKLAND' 'IRVINE' 'PLEASANT GROVE' 'BELLE CHASSE' 'Olney' 'MT PLEASANT'
#  'PASADENA' 'EL CERRITO' 'NORTH PROVIDENCE' 'Charlotte' 'CORAL GABLES'
#  'PETALUMA' 'Boston' 'FISHERS (CORPORATE NAME FOR FI'] ...
# Unique values in 'State': ['CT' 'IL' 'CA' 'TX' 'MI' 'WA' 'UT' 'LA' 'MD' 'RI' 'NC' 'FL' 'MA' 'IN'
#  'NM' 'NV' 'MN' 'NY' 'AZ' 'VT'] ...
# Unique values in 'Bank': ['TD BANK, NATIONAL ASSOCIATION' 'BANK OF AMERICA NATL ASSOC'
#  'WELLS FARGO BANK NATL ASSOC' 'THE FROST NATIONAL BANK' 'BBCN BANK'
#  'MOUNTAIN W. SMALL BUS. FINAN' 'GULF COAST BK & TR CO'
#  'WISCONSIN BANK & TRUST' 'MUFG UNION BANK NATL ASSOC'
#  'GE CAP. SMALL BUS. FINAN CORP' 'FLORIDA BUS. DEVEL CORP'
#  'BANK OF AMERICA CALIFORNIA N.A' 'PNC BANK, NATIONAL ASSOCIATION'
#  'COMPASS BANK' 'SAFE-BIDCO' 'FIRST MINNETONKA CITY BANK'
#  'MONROE CNTY INDUST DEVEL CORP' 'JPMORGAN CHASE BANK NATL ASSOC'
#  'KEYBANK NATIONAL ASSOCIATION' 'MOUNTAIN W. BANK NATL ASSOC'] ...
# Unique values in 'BankState': ['DE' 'OR' 'SD' 'TX' 'CA' 'WA' 'UT' 'LA' 'WI' 'NC' 'FL' 'RI' 'MN' 'NY'
#  'IL' 'OH' 'MT' 'MI' 'ND' 'MD'] ...
# Unique values in 'NAICS': ['Manufacturing' 'Construction' 'Educational services'
#  'Health care and social assistance' 'Arts, entertainment, and recreation'
#  'Retail trade' 'Wholesale trade'
#  'Professional, scientific, and technical services'
#  'Accommodation and food services'
#  'Other services (except public administration)'
#  'Administrative and support and waste management and remediation services'
#  'Information' 'Agriculture, forestry, fishing and hunting'
#  'Real estate and rental and leasing' 'Transportation and warehousing'
#  'Finance and insurance' 'Mining, quarrying, and oil and gas extraction'
#  'Utilities' 'Public administration'
#  'Management of companies and enterprises'] ...
# Unique values in 'ApprovalDate': ['2/28/1997' '2/7/2006' '3/31/1997' '5/5/1997' '5/23/1997' '5/29/1997'
#  '6/23/1997' '7/10/1997' '7/16/1997' '7/21/1997' '8/26/1997' '1/15/1998'
#  '2/23/1998' '3/26/1998' '5/20/1998' '5/26/1998' '6/2/1998' '6/30/1998'
#  '9/15/1998' '9/25/1998'] ...
# Unique values in 'RevLineCr': ['N' 'Y' '0' 'T' nan '`' '1' 'C' 'R' '2' '7'] ...
# Unique values in 'LowDoc': ['N' 'Y'] ...
# Unique values in 'ChgOffDate': [nan '10/4/2005' '8/16/2010' '5/5/2010' '5/16/2006' '12/6/2010'
#  '12/28/2005' '1/28/2010' '6/6/2008' '3/12/2013' '8/19/2010' '4/6/2011'
#  '7/24/2012' '9/23/2011' '10/19/2010' '7/20/2006' '8/23/2010' '11/10/2010'
#  '7/29/2005' '3/24/2010'] ...
# Unique values in 'DisbursementDate': ['6/30/1997' '11/30/1997' '2/28/2006' '7/31/1997' '2/28/1998' '12/31/1997'
#  '3/31/2006' '6/11/1997' '10/31/1997' '3/31/1997' '1/31/1998' '3/31/2001'
#  '9/17/1997' '7/31/2000' '9/30/1997' '4/30/1997' '8/31/2000' '5/31/1998'
#  '11/12/1997' '4/30/1998'] ...
# Unique values in 'Loan_backed_Realestate': ['Not Backed' 'Backed'] ...
# Unique values in 'Frequence_of_apps': ['Low'] ...
# Unique values in 'payment_consistency': ['regular' 'sporadic' 'periodic' nan] ...
# Unique values in 'Credit Utilizations': ['No data' 'Low' 'High'] ...
# Unique values in 'Late Payment': ['N' 'Y'] ...
# Unique values in 'Taxed_filed': ['YES' 'PENDING' 'EXEMPT' 'LATE' 'NO'] ...
# Unique values in 'Business Licenses Status': ['YES' 'RENEWAL DUE' 'NOT REQUIRED' 'EXPIRED' 'UNDER AUDIT' 'NO'] ...
# Unique values in 'Fraud Trend Over Time': ['Stable'] ...
# Unique values in 'Purpose_of_credit': ['Equipment & Technology Upgrades'
#  'Working Capital & Cash Flow Management'
#  'Emergency & Unforeseen Expenses' 'Business Expansion & Growth'
#  'Marketing & Advertising' 'Hiring & Payroll Support'
#  'Contract Fulfillment' 'Inventory & Supply Purchases'] ...

# %%
df.head(10)
# Out:
#    LoanNr_ChkDgt                            Name            City State    Zip  \
# 0     1000084002  B&T SCREW MACHINE COMPANY, INC      PLAINVILLE    CT   6062
# 1     1000144007  PROFESSIONAL ELEVATOR SERVICES         CHICAGO    IL  60605
# 2     1000506000             WEYLAND CORPORATION       CAMARILLO    CA  93010
# 3     1000524003     AUDELIA FAMILY DENTAL GROUP          DALLAS    TX  75243
# 4     1000735003              Mykols Marine Inc.     Spring Lake    MI  49417
# 5     1000746002                           ANGEL     LOS ANGELES    CA  60014
# 6     1000764005            LABELLE MARIEE, INC.        KIRKLAND    WA  98033
# 7     1000816010               TULON PACIFIC LLC          IRVINE    CA  92618
# 8     1000844005        WOODLAND PUBLISHING, INC  PLEASANT GROVE    UT  84062
# 9     1000926008       TOUCHPOINTS MARKETING LLC    BELLE CHASSE    LA  70037
#
#                             Bank BankState  \
# 0  TD BANK, NATIONAL ASSOCIATION        DE
# 1     BANK OF AMERICA NATL ASSOC        OR
# 2    WELLS FARGO BANK NATL ASSOC        SD
# 3        THE FROST NATIONAL BANK        TX
# 4    WELLS FARGO BANK NATL ASSOC        SD
# 5                      BBCN BANK        CA
# 6     BANK OF AMERICA NATL ASSOC        WA
# 7    WELLS FARGO BANK NATL ASSOC        SD
# 8   MOUNTAIN W. SMALL BUS. FINAN        UT
# 9          GULF COAST BK & TR CO        LA
#
#                                               NAICS ApprovalDate  ApprovalFY  \
# 0                                     Manufacturing    2/28/1997        1997
# 1                                      Construction    2/28/1997        1997
# 2                              Educational services     2/7/2006        2006
# 3                 Health care and social assistance    2/28/1997        1997
# 4               Arts, entertainment, and recreation    3/31/1997        1997
# 5                                     Manufacturing     2/7/2006        2006
# 6                                      Retail trade    2/28/1997        1997
# 7                                   Wholesale trade     2/7/2006        2006
# 8                                     Manufacturing    2/28/1997        1997
# 9  Professional, scientific, and technical services     2/7/2006        2006
#
#    ...  Late Payment  Annual Revenue     Net income  Credit Score  \
# 0  ...             N    1.730830e+06  150539.304000           612
# 1  ...             N    5.417385e+05   27314.406130           601
# 2  ...             N    2.636591e+06  131829.564900           497
# 3  ...             N    3.595876e+06  179793.796300           547
# 4  ...             N    1.290236e+05    6451.179845           628
# 5  ...             N    2.950828e+05   21851.532240           454
# 6  ...             N    2.214847e+05   11074.234950           725
# 7  ...             N    3.488753e+06  174437.663900           488
# 8  ...             N    7.115627e+05   46337.090610           778
# 9  ...             N    9.803569e+05   49017.846900           483
#
#    Taxed_filed  Business Licenses Status  Outstanding loans  \
# 0          YES                       YES               11.0
# 1      PENDING               RENEWAL DUE                8.0
# 2      PENDING              NOT REQUIRED                1.0
# 3       EXEMPT               RENEWAL DUE               13.0
# 4       EXEMPT              NOT REQUIRED               10.0
# 5       EXEMPT                       YES                1.0
# 6      PENDING              NOT REQUIRED                5.0
# 7       EXEMPT               RENEWAL DUE               15.0
# 8      PENDING               RENEWAL DUE                1.0
# 9       EXEMPT              NOT REQUIRED                4.0
#
#   Fraud Trend Over Time fraud_incident                       Purpose_of_credit
# 0                Stable              0         Equipment & Technology Upgrades
# 1                Stable              0         Equipment & Technology Upgrades
# 2                Stable              0  Working Capital & Cash Flow Management
# 3                Stable              1         Emergency & Unforeseen Expenses
# 4                Stable              0         Equipment & Technology Upgrades
# 5                Stable              0  Working Capital & Cash Flow Management
# 6                Stable              0         Emergency & Unforeseen Expenses
# 7                Stable              0             Business Expansion & Growth
# 8                Stable              1                 Marketing & Advertising
# 9                Stable              1  Working Capital & Cash Flow Management
#
# [10 rows x 42 columns]

# %%
print(df.isnull().mean() * 100)

missing_values = df.isnull().sum().sort_values(ascending=False)
print("Missing Values Count:\n", missing_values[missing_values > 0])

missing_percent = (df.isnull().sum() / len(df)) * 100
missing_percent = missing_percent[missing_percent > 0].sort_values(ascending=False)

plt.figure(figsize=(12, 5))
missing_percent.plot(kind="bar", color="red")

plt.title("Percentage of Missing Values Per Column")
plt.xlabel("Columns")
plt.ylabel("Percentage of Missing Values")
plt.xticks(rotation=90)

#This is to show missing values for features which are less than 1%
plt.ylim(0, max(missing_percent) + 1)  # Adjust the y-axis to include small percentages
plt.savefig("images/missing_data_metrics.png", dpi=300)
plt.show()
# Out:
# LoanNr_ChkDgt                 0.000000
# Name                          0.000000
# City                          0.000000
# State                         0.001000
# Zip                           0.000000
# Bank                          0.181002
# BankState                     0.182002
# NAICS                         0.000000
# ApprovalDate                  0.000000
# ApprovalFY                    0.000000
# Term                          0.000000
# NoEmp                         0.000000
# NewExist                      0.036000
# CreateJob                     0.000000
# RetainedJob                   0.000000
# FranchiseCode                 0.000000
# UrbanRural                    0.000000
# RevLineCr                     0.264003
# LowDoc                        0.000000
# ChgOffDate                   84.408844
# DisbursementDate              0.275003
# DisbursementGross             0.000000
# BalanceGross                  0.000000
# Fraud/Shell company Fraud     0.149001
# ChgOffPrinGr                  0.000000
# GrAppv                        0.000000
# Sector_Code                   0.000000
# Loan_backed_Realestate        0.000000
# NumOfapplications             0.000000
# Frequence_of_apps             0.000000
# payment_consistency           0.036000
# Credit Utilizations           0.000000
# Late Payment                  0.000000
# Annual Revenue                0.000000
# Net income                    0.000000
# Credit Score                  0.000000
# Taxed_filed                   0.000000
# Business Licenses Status      0.000000
# Outstanding loans             0.122001
# Fraud Trend Over Time         0.000000
# fraud_incident                0.000000
# Purpose_of_credit             0.000000
# dtype: float64
# Missing Values Count:
#  ChgOffDate                   84408
# DisbursementDate               275
# RevLineCr                      264
# BankState                      182
# Bank                           181
# Fraud/Shell company Fraud      149
# Outstanding loans              122
# NewExist                        36
# payment_consistency             36
# State                            1
# dtype: int64

# %%
#Lets drop columns that do not add values and has no data 

df_clean = df.drop(columns=['LoanNr_ChkDgt','ChgOffDate','ApprovalDate','ApprovalFY','DisbursementDate', 'Fraud Trend Over Time','Name','City','Bank','BalanceGross','ChgOffPrinGr','GrAppv','Sector_Code','Frequence_of_apps'], axis=1)
df_clean.info()

#Outstanding loans, Fraud/Shell company Fraud, Bank, BankState, RevLineCr, payment_consistency
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      99998 non-null  object
#  1   Zip                        99999 non-null  int64
#  2   BankState                  99817 non-null  object
#  3   NAICS                      99999 non-null  object
#  4   Term                       99999 non-null  int64
#  5   NoEmp                      99999 non-null  int64
#  6   NewExist                   99963 non-null  float64
#  7   CreateJob                  99999 non-null  int64
#  8   RetainedJob                99999 non-null  int64
#  9   FranchiseCode              99999 non-null  int64
#  10  UrbanRural                 99999 non-null  int64
#  11  RevLineCr                  99735 non-null  object
#  12  LowDoc                     99999 non-null  object
#  13  DisbursementGross          99999 non-null  int64
#  14  Fraud/Shell company Fraud  99850 non-null  float64
#  15  Loan_backed_Realestate     99999 non-null  object
#  16  NumOfapplications          99999 non-null  int64
#  17  payment_consistency        99963 non-null  object
#  18  Credit Utilizations        99999 non-null  object
#  19  Late Payment               99999 non-null  object
#  20  Annual Revenue             99999 non-null  float64
#  21  Net income                 99999 non-null  float64
#  22  Credit Score               99999 non-null  int64
#  23  Taxed_filed                99999 non-null  object
#  24  Business Licenses Status   99999 non-null  object
#  25  Outstanding loans          99877 non-null  float64
#  26  fraud_incident             99999 non-null  int64
#  27  Purpose_of_credit          99999 non-null  object
# dtypes: float64(5), int64(11), object(12)
# memory usage: 21.4+ MB

# %%
#Lets do some univariant and bivariant analysis and correlation heatmap to understand the relationship between the independent and dependent variables

# Histogram for Annual Revenue
fig, axes = plt.subplots(1, 3, figsize=(10, 6))
sns.histplot(df_clean['Annual Revenue'], bins=30, kde=True,ax=axes[0])
axes[0].set_title("Distribution of Annual Revenue")

sns.histplot(df_clean['Term'], bins=30, kde=True,ax=axes[1])
axes[1].set_title("Distribution of Term")

sns.histplot(df_clean['DisbursementGross'], bins=30, kde=True, ax=axes[2])
axes[2].set_title("Distribution of Credit Request(DisbursementGross)")
plt.tight_layout()  # Adjust spacing
plt.savefig("images/barplot_for_Distribution_metrics.png", dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Annual Revenue'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 5
#       1 #Lets do some univariant and bivariant analysis and correlation heatmap to understand the relationship between the independent and dependent variables
#       2
#       3 # Histogram for Annual Revenue
#       4 fig, axes = plt.subplots(1, 3, figsize=(10, 6))
# ----> 5 sns.histplot(df_clean['Annual Revenue'], bins=30, kde=True,ax=axes[0])
#       6 axes[0].set_title("Distribution of Annual Revenue")
#       8 sns.histplot(df_clean['Term'], bins=30, kde=True,ax=axes[1])
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Annual Revenue'

# %%
# Boxplot for detecting outliers - NoEmp, Term, DisbursementGross, NumOfApplications, Annual Revenue, Net Income, Credit Score
import matplotlib.pyplot as plt
import seaborn as sns

# Define columns for boxplots
columns = ['Credit Score', 'NoEmp', 'DisbursementGross', 'NumOfapplications', 
           'Annual Revenue', 'Net income', 'CreateJob','RetainedJob']

# Filter out missing columns (to prevent KeyError)
columns = [col for col in columns if col in df_clean.columns]

# Set up subplots dynamically based on available columns
fig, axes = plt.subplots(1, len(columns), figsize=(3 * len(columns), 7))  # Adjust width dynamically

# Ensure axes is iterable (handles cases where only one column exists)
if len(columns) == 1:
    axes = [axes]

# Loop through each column and plot boxplots
for i, col in enumerate(columns):
    sns.boxplot(x=df[col], ax=axes[i], notch=True)
    axes[i].set_title(f"Boxplot of {col}")
    axes[i].set_xlabel("")  # Remove x-axis label for clarity
    axes[i].tick_params(axis='x', rotation=45)  # Rotate x-ticks if necessary

# Adjust layout and spacing
plt.subplots_adjust(wspace=0.5)  # Increase spacing between plots for clarity
plt.tight_layout()
plt.savefig("images/boxplot_for_Outlier_metrics.png", dpi=300)
plt.show()

# %%
#Frequence of the variable State, Loan Purpose, Payment Consistency
# Bar chart for Payment Consistency
# Create a figure with subplots (2 rows, 2 columns)
fig, axes = plt.subplots(2, 2, figsize=(20, 16))

# Plot 1: Payment Consistency
sns.countplot(x=df_clean['payment_consistency'], ax=axes[0, 0])
axes[0, 0].set_title("Frequency of Payment Consistency")
axes[0, 0].tick_params(axis='x', rotation=45)

# Plot 2: Purpose of Credit
sns.countplot(x=df_clean['Purpose_of_credit'], ax=axes[0, 1])
axes[0, 1].set_title("Frequency of Purpose_of_credit")
axes[0, 1].tick_params(axis='x', rotation=90)

# Plot 3: NAICS
sns.countplot(x=df_clean['NAICS'], ax=axes[1, 0])
axes[1, 0].set_title("Frequency of NAICS")
axes[1, 0].tick_params(axis='x', rotation=90)

# Plot 4: State
sns.countplot(x=df_clean['State'], ax=axes[1, 1])
axes[1, 1].set_title("Frequency of State")
axes[1, 1].tick_params(axis='x', rotation=90)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig("images/barplot_for_Frequency_metrics.png", dpi=300)
plt.show()

# %%
#Pie Chart	Proportion of categories	Loan-backed Real Estate, RevLineCr	df['RevLineCr'].value_counts().plot.pie()
#KDE Plot	Smooth distribution of numerical data	Net Income, Balance Gross	sns.kdeplot(df['Net income'], shade=True)

# Create a figure with 1 row, 2 columns for subplots
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# Pie Chart 1: `RevLineCr`
df_clean['RevLineCr'].value_counts().plot.pie(autopct='%1.1f%%', ax=axes[0], colors=['skyblue', 'lightcoral'])
axes[0].set_title("Revolving Line of Credit (RevLineCr)")
axes[0].set_ylabel('')  # Hide y-label for better display

# Pie Chart 2: `Loan_backed_Realestate`
df_clean['Loan_backed_Realestate'].value_counts().plot.pie(autopct='%1.1f%%', ax=axes[1], colors=['gold', 'lightgreen'])
axes[1].set_title("Loan Backed by Real Estate")
axes[1].set_ylabel('')  # Hide y-label for better display

# Display the pie charts
plt.tight_layout()
plt.savefig("images/piechart_for_distribution_percentage_metrics.png", dpi=300)
plt.show()

# %%
#Bivariant analysis 
fig, axes = plt.subplots(2, 2, figsize=(20, 16))
sns.scatterplot(x=df_clean['DisbursementGross'], y=df_clean['Annual Revenue'], ax=axes[0, 0], hue=df_clean['Fraud/Shell company Fraud'])
axes[0, 0].set_title("Credit Requested vs. Annual Revenue")
axes[0, 0].tick_params(axis='x', rotation=45)

sns.scatterplot(x=df_clean['DisbursementGross'], y=df_clean['NAICS'], ax=axes[0, 1], hue=df_clean['Fraud/Shell company Fraud'])
axes[0, 1].set_title("Credit Requested vs.NAICS")
axes[0, 1].tick_params(axis='x', rotation=45)

sns.scatterplot(x=df_clean['DisbursementGross'], y=df_clean['NoEmp'], ax=axes[1, 0], hue=df_clean['Fraud/Shell company Fraud'])
axes[1, 0].set_title("Credit Requested vs. NoEmp")
axes[1, 0].tick_params(axis='x', rotation=45)

sns.scatterplot(x=df_clean['DisbursementGross'], y=df_clean['Term'], ax=axes[1, 1], hue=df_clean['Fraud/Shell company Fraud'])
axes[1, 1].set_title("Credit Requested vs. Term")
axes[1, 1].tick_params(axis='x', rotation=45)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig("images/scatterplot_for_creditRequestedvsfeatures.png", dpi=300)
plt.show()

# %%
# Heatmap - Correlation Matrix
# Select only numeric columns
numeric_df = df_clean.select_dtypes(include=['int','float'])  # Keeps only numerical columns

numeric_df= numeric_df.drop(columns=['Zip'], axis=1)
# Compute correlation matrix
correlation_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))  # Adjust figure size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Numeric Features")
plt.savefig("images/heatmap_for_correlation.png", dpi=300)
plt.show()

# %%
#Drop other unwanted columns
# Step 2: Impute missing 'Annual Revenue' with the median value
revenue_imputer = SimpleImputer(strategy='median')
df_clean['Annual Revenue'] = revenue_imputer.fit_transform(df_clean[['Annual Revenue']])

#Step 3 : Impute missing 'Outstanding loans' with the median value
df_clean['Outstanding loans'] = df_clean['Outstanding loans'].fillna(df_clean['Outstanding loans'].median())

# Categorical columns: Fill missing values with Mode (Most Frequent Value)
for col in ['Fraud/Shell company Fraud', 'BankState', 'RevLineCr', 'payment_consistency','NewExist', 'State']:
    df_clean[col] = df_clean[col].fillna(df_clean[col].mode()[0])  # mode()[0] gets the most frequent value

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      99999 non-null  object
#  1   Zip                        99999 non-null  int64
#  2   BankState                  99999 non-null  object
#  3   NAICS                      99999 non-null  object
#  4   Term                       99999 non-null  int64
#  5   NoEmp                      99999 non-null  int64
#  6   NewExist                   99999 non-null  float64
#  7   CreateJob                  99999 non-null  int64
#  8   RetainedJob                99999 non-null  int64
#  9   FranchiseCode              99999 non-null  int64
#  10  UrbanRural                 99999 non-null  int64
#  11  RevLineCr                  99999 non-null  object
#  12  LowDoc                     99999 non-null  object
#  13  DisbursementGross          99999 non-null  int64
#  14  Fraud/Shell company Fraud  99999 non-null  float64
#  15  Loan_backed_Realestate     99999 non-null  object
#  16  NumOfapplications          99999 non-null  int64
#  17  payment_consistency        99999 non-null  object
#  18  Credit Utilizations        99999 non-null  object
#  19  Late Payment               99999 non-null  object
#  20  Annual Revenue             99999 non-null  float64
#  21  Net income                 99999 non-null  float64
#  22  Credit Score               99999 non-null  int64
#  23  Taxed_filed                99999 non-null  object
#  24  Business Licenses Status   99999 non-null  object
#  25  Outstanding loans          99999 non-null  float64
#  26  fraud_incident             99999 non-null  int64
#  27  Purpose_of_credit          99999 non-null  object
# dtypes: float64(5), int64(11), object(12)
# memory usage: 21.4+ MB

# %%
##FranchiseCode 0 or 1 is no franchise - otherwise its franchise
df_clean['FranchiseCode'] = df_clean['FranchiseCode'].apply(lambda x: 0 if x <= 1 else 1)

# %%
#converting categorical data to numerical data 
#state, zipcode, NAICS, Loan_backed_Realestate, RevLineCr, LowDoc, Frequence_of_apps ,payment_consistency, Credit Utilizations, late_payment, Tax_filee, Business_license_status, Purpose of credit.         
#converting zipcode by using frequency encoding

# Frequency Encoding for Zipcode, RevLinCr
zip_counts = df_clean['Zip'].value_counts()  
df_clean['Zip'] = df_clean['Zip'].map(zip_counts)  
RevLinCr_counts = df_clean['RevLineCr'].value_counts()  
df_clean['RevLinCr'] = df_clean['RevLineCr'].map(RevLinCr_counts)

#Binary Encoding for columns
binary_columns = ['Loan_backed_Realestate', 'LowDoc', 'Late Payment']
for col in binary_columns:
    df_clean[col] = df_clean[col].map({'Yes': 1, 'No': 0, 'Y': 1, 'N': 0, 'Backed':1, 'Not Backed':0})

#Ordinal encoding
ordinal_mapping = {
    'payment_consistency': {'None':0, 'sporadic': 1, 'periodic': 2, 'regular': 3 },
    'Credit Utilizations': {'No data': 1, 'Low': 2, 'High': 3},
    'Taxed_filed':{'NO':0, 'PENDING': 1, 'LATE':2, 'YES':3,'EXEMPT':4},
    'Business Licenses Status':{'NO':0, 'EXPIRED': 1, 'UNDER AUDIT': 2,'RENEWAL DUE': 3,'NOT REQUIRED': 4,'YES': 5}
}
for col, mapping in ordinal_mapping.items():
    df_clean[col] = df_clean[col].map(mapping)

#target Encoding for State. Compute target mean per category
state_target_mean = df_clean.groupby('State')['fraud_incident'].mean()
bank_state_target_mean = df_clean.groupby('BankState')['fraud_incident'].mean()

# Apply target encoding
df_clean['State'] = df_clean['State'].map(state_target_mean)
df_clean['BankState']=df_clean['BankState'].map(bank_state_target_mean)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      99999 non-null  float64
#  1   Zip                        99999 non-null  int64
#  2   BankState                  99999 non-null  float64
#  3   NAICS                      99999 non-null  object
#  4   Term                       99999 non-null  int64
#  5   NoEmp                      99999 non-null  int64
#  6   NewExist                   99999 non-null  float64
#  7   CreateJob                  99999 non-null  int64
#  8   RetainedJob                99999 non-null  int64
#  9   FranchiseCode              99999 non-null  int64
#  10  UrbanRural                 99999 non-null  int64
#  11  RevLineCr                  99999 non-null  object
#  12  LowDoc                     99999 non-null  int64
#  13  DisbursementGross          99999 non-null  int64
#  14  Fraud/Shell company Fraud  99999 non-null  float64
#  15  Loan_backed_Realestate     99999 non-null  int64
#  16  NumOfapplications          99999 non-null  int64
#  17  payment_consistency        99999 non-null  int64
#  18  Credit Utilizations        99999 non-null  int64
#  19  Late Payment               99999 non-null  int64
#  20  Annual Revenue             99999 non-null  float64
#  21  Net income                 99999 non-null  float64
#  22  Credit Score               99999 non-null  int64
#  23  Taxed_filed                99999 non-null  int64
#  24  Business Licenses Status   99999 non-null  int64
#  25  Outstanding loans          99999 non-null  float64
#  26  fraud_incident             99999 non-null  int64
#  27  Purpose_of_credit          99999 non-null  object
#  28  RevLinCr                   99999 non-null  int64
# dtypes: float64(7), int64(19), object(3)
# memory usage: 22.1+ MB

# %%
#One Hot encoding for NAICS and Purpose_of_credit

# Perform one-hot encoding
encoded_condition = pd.get_dummies(df_clean['NAICS'], prefix='NAICS').astype(int)
# Combine with original DataFrame
df_clean = pd.concat([df_clean, encoded_condition], axis=1)

# Perform one-hot encoding
encoded_condition_purpose = pd.get_dummies(df_clean['Purpose_of_credit'], prefix='Purpose_of_credit').astype(int)

# Combine with original DataFrame
df_clean = pd.concat([df_clean, encoded_condition_purpose], axis=1)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 57 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   State                                                                           99999 non-null  float64
#  1   Zip                                                                             99999 non-null  int64
#  2   BankState                                                                       99999 non-null  float64
#  3   NAICS                                                                           99999 non-null  object
#  4   Term                                                                            99999 non-null  int64
#  5   NoEmp                                                                           99999 non-null  int64
#  6   NewExist                                                                        99999 non-null  float64
#  7   CreateJob                                                                       99999 non-null  int64
#  8   RetainedJob                                                                     99999 non-null  int64
#  9   FranchiseCode                                                                   99999 non-null  int64
#  10  UrbanRural                                                                      99999 non-null  int64
#  11  RevLineCr                                                                       99999 non-null  object
#  12  LowDoc                                                                          99999 non-null  int64
#  13  DisbursementGross                                                               99999 non-null  int64
#  14  Fraud/Shell company Fraud                                                       99999 non-null  float64
#  15  Loan_backed_Realestate                                                          99999 non-null  int64
#  16  NumOfapplications                                                               99999 non-null  int64
#  17  payment_consistency                                                             99999 non-null  int64
#  18  Credit Utilizations                                                             99999 non-null  int64
#  19  Late Payment                                                                    99999 non-null  int64
#  20  Annual Revenue                                                                  99999 non-null  float64
#  21  Net income                                                                      99999 non-null  float64
#  22  Credit Score                                                                    99999 non-null  int64
#  23  Taxed_filed                                                                     99999 non-null  int64
#  24  Business Licenses Status                                                        99999 non-null  int64
#  25  Outstanding loans                                                               99999 non-null  float64
#  26  fraud_incident                                                                  99999 non-null  int64
#  27  Purpose_of_credit                                                               99999 non-null  object
#  28  RevLinCr                                                                        99999 non-null  int64
#  29  NAICS_Accommodation and food services                                           99999 non-null  int32
#  30  NAICS_Administrative and support and waste management and remediation services  99999 non-null  int32
#  31  NAICS_Agriculture, forestry, fishing and hunting                                99999 non-null  int32
#  32  NAICS_Arts, entertainment, and recreation                                       99999 non-null  int32
#  33  NAICS_Construction                                                              99999 non-null  int32
#  34  NAICS_Educational services                                                      99999 non-null  int32
#  35  NAICS_Finance and insurance                                                     99999 non-null  int32
#  36  NAICS_Health care and social assistance                                         99999 non-null  int32
#  37  NAICS_Information                                                               99999 non-null  int32
#  38  NAICS_Management of companies and enterprises                                   99999 non-null  int32
#  39  NAICS_Manufacturing                                                             99999 non-null  int32
#  40  NAICS_Mining, quarrying, and oil and gas extraction                             99999 non-null  int32
#  41  NAICS_Other services (except public administration)                             99999 non-null  int32
#  42  NAICS_Professional, scientific, and technical services                          99999 non-null  int32
#  43  NAICS_Public administration                                                     99999 non-null  int32
#  44  NAICS_Real estate and rental and leasing                                        99999 non-null  int32
#  45  NAICS_Retail trade                                                              99999 non-null  int32
#  46  NAICS_Transportation and warehousing                                            99999 non-null  int32
#  47  NAICS_Utilities                                                                 99999 non-null  int32
#  48  NAICS_Wholesale trade                                                           99999 non-null  int32
#  49  Purpose_of_credit_Business Expansion & Growth                                   99999 non-null  int32
#  50  Purpose_of_credit_Contract Fulfillment                                          99999 non-null  int32
#  51  Purpose_of_credit_Emergency & Unforeseen Expenses                               99999 non-null  int32
#  52  Purpose_of_credit_Equipment & Technology Upgrades                               99999 non-null  int32
#  53  Purpose_of_credit_Hiring & Payroll Support                                      99999 non-null  int32
#  54  Purpose_of_credit_Inventory & Supply Purchases                                  99999 non-null  int32
#  55  Purpose_of_credit_Marketing & Advertising                                       99999 non-null  int32
#  56  Purpose_of_credit_Working Capital & Cash Flow Management                        99999 non-null  int32
# dtypes: float64(7), int32(28), int64(19), object(3)
# memory usage: 32.8+ MB

# %%
#lets change column name for better readability 
df_clean.columns = df_clean.columns.str.replace(" ", "_")
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 57 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   State                                                                           99999 non-null  float64
#  1   Zip                                                                             99999 non-null  int64
#  2   BankState                                                                       99999 non-null  float64
#  3   NAICS                                                                           99999 non-null  object
#  4   Term                                                                            99999 non-null  int64
#  5   NoEmp                                                                           99999 non-null  int64
#  6   NewExist                                                                        99999 non-null  float64
#  7   CreateJob                                                                       99999 non-null  int64
#  8   RetainedJob                                                                     99999 non-null  int64
#  9   FranchiseCode                                                                   99999 non-null  int64
#  10  UrbanRural                                                                      99999 non-null  int64
#  11  RevLineCr                                                                       99999 non-null  object
#  12  LowDoc                                                                          99999 non-null  int64
#  13  DisbursementGross                                                               99999 non-null  int64
#  14  Fraud/Shell_company_Fraud                                                       99999 non-null  float64
#  15  Loan_backed_Realestate                                                          99999 non-null  int64
#  16  NumOfapplications                                                               99999 non-null  int64
#  17  payment_consistency                                                             99999 non-null  int64
#  18  Credit_Utilizations                                                             99999 non-null  int64
#  19  Late_Payment                                                                    99999 non-null  int64
#  20  Annual_Revenue                                                                  99999 non-null  float64
#  21  Net_income                                                                      99999 non-null  float64
#  22  Credit_Score                                                                    99999 non-null  int64
#  23  Taxed_filed                                                                     99999 non-null  int64
#  24  Business_Licenses_Status                                                        99999 non-null  int64
#  25  Outstanding_loans                                                               99999 non-null  float64
#  26  fraud_incident                                                                  99999 non-null  int64
#  27  Purpose_of_credit                                                               99999 non-null  object
#  28  RevLinCr                                                                        99999 non-null  int64
#  29  NAICS_Accommodation_and_food_services                                           99999 non-null  int32
#  30  NAICS_Administrative_and_support_and_waste_management_and_remediation_services  99999 non-null  int32
#  31  NAICS_Agriculture,_forestry,_fishing_and_hunting                                99999 non-null  int32
#  32  NAICS_Arts,_entertainment,_and_recreation                                       99999 non-null  int32
#  33  NAICS_Construction                                                              99999 non-null  int32
#  34  NAICS_Educational_services                                                      99999 non-null  int32
#  35  NAICS_Finance_and_insurance                                                     99999 non-null  int32
#  36  NAICS_Health_care_and_social_assistance                                         99999 non-null  int32
#  37  NAICS_Information                                                               99999 non-null  int32
#  38  NAICS_Management_of_companies_and_enterprises                                   99999 non-null  int32
#  39  NAICS_Manufacturing                                                             99999 non-null  int32
#  40  NAICS_Mining,_quarrying,_and_oil_and_gas_extraction                             99999 non-null  int32
#  41  NAICS_Other_services_(except_public_administration)                             99999 non-null  int32
#  42  NAICS_Professional,_scientific,_and_technical_services                          99999 non-null  int32
#  43  NAICS_Public_administration                                                     99999 non-null  int32
#  44  NAICS_Real_estate_and_rental_and_leasing                                        99999 non-null  int32
#  45  NAICS_Retail_trade                                                              99999 non-null  int32
#  46  NAICS_Transportation_and_warehousing                                            99999 non-null  int32
#  47  NAICS_Utilities                                                                 99999 non-null  int32
#  48  NAICS_Wholesale_trade                                                           99999 non-null  int32
#  49  Purpose_of_credit_Business_Expansion_&_Growth                                   99999 non-null  int32
#  50  Purpose_of_credit_Contract_Fulfillment                                          99999 non-null  int32
#  51  Purpose_of_credit_Emergency_&_Unforeseen_Expenses                               99999 non-null  int32
#  52  Purpose_of_credit_Equipment_&_Technology_Upgrades                               99999 non-null  int32
#  53  Purpose_of_credit_Hiring_&_Payroll_Support                                      99999 non-null  int32
#  54  Purpose_of_credit_Inventory_&_Supply_Purchases                                  99999 non-null  int32
#  55  Purpose_of_credit_Marketing_&_Advertising                                       99999 non-null  int32
#  56  Purpose_of_credit_Working_Capital_&_Cash_Flow_Management                        99999 non-null  int32
# dtypes: float64(7), int32(28), int64(19), object(3)
# memory usage: 32.8+ MB

# %%
#Lets remove the outliers from the data using IQR and z-score
print("Original size:", df_clean.shape)
# Function to remove outliers using IQR
def remove_outliers(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)  # 25th percentile
        Q3 = df[col].quantile(0.75)  # 75th percentile
        IQR = Q3 - Q1  # Interquartile range
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        # Keep only values within the bounds
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# List of numerical columns to clean
num_cols = ['Credit_Score', 'NoEmp', 'NumOfapplications', 'Annual_Revenue', 'Net_income','Term']

# Remove outliers from selected columns
df_clean = remove_outliers(df_clean, num_cols)

df_clean["DisbursementGross"] = np.log1p(df_clean["DisbursementGross"])  # Applies log(1+x) to prevent log(0) issues

# Check the new shape of the dataset
print("New size after outlier removal:", df_clean.shape)
# Out:
# Original size: (99999, 57)
# New size after outlier removal: (63983, 57)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63983 entries, 0 to 99996
# Data columns (total 57 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   State                                                                           63983 non-null  float64
#  1   Zip                                                                             63983 non-null  int64
#  2   BankState                                                                       63983 non-null  float64
#  3   NAICS                                                                           63983 non-null  object
#  4   Term                                                                            63983 non-null  int64
#  5   NoEmp                                                                           63983 non-null  int64
#  6   NewExist                                                                        63983 non-null  float64
#  7   CreateJob                                                                       63983 non-null  int64
#  8   RetainedJob                                                                     63983 non-null  int64
#  9   FranchiseCode                                                                   63983 non-null  int64
#  10  UrbanRural                                                                      63983 non-null  int64
#  11  RevLineCr                                                                       63983 non-null  object
#  12  LowDoc                                                                          63983 non-null  int64
#  13  DisbursementGross                                                               63983 non-null  float64
#  14  Fraud/Shell_company_Fraud                                                       63983 non-null  float64
#  15  Loan_backed_Realestate                                                          63983 non-null  int64
#  16  NumOfapplications                                                               63983 non-null  int64
#  17  payment_consistency                                                             63983 non-null  int64
#  18  Credit_Utilizations                                                             63983 non-null  int64
#  19  Late_Payment                                                                    63983 non-null  int64
#  20  Annual_Revenue                                                                  63983 non-null  float64
#  21  Net_income                                                                      63983 non-null  float64
#  22  Credit_Score                                                                    63983 non-null  int64
#  23  Taxed_filed                                                                     63983 non-null  int64
#  24  Business_Licenses_Status                                                        63983 non-null  int64
#  25  Outstanding_loans                                                               63983 non-null  float64
#  26  fraud_incident                                                                  63983 non-null  int64
#  27  Purpose_of_credit                                                               63983 non-null  object
#  28  RevLinCr                                                                        63983 non-null  int64
#  29  NAICS_Accommodation_and_food_services                                           63983 non-null  int32
#  30  NAICS_Administrative_and_support_and_waste_management_and_remediation_services  63983 non-null  int32
#  31  NAICS_Agriculture,_forestry,_fishing_and_hunting                                63983 non-null  int32
#  32  NAICS_Arts,_entertainment,_and_recreation                                       63983 non-null  int32
#  33  NAICS_Construction                                                              63983 non-null  int32
#  34  NAICS_Educational_services                                                      63983 non-null  int32
#  35  NAICS_Finance_and_insurance                                                     63983 non-null  int32
#  36  NAICS_Health_care_and_social_assistance                                         63983 non-null  int32
#  37  NAICS_Information                                                               63983 non-null  int32
#  38  NAICS_Management_of_companies_and_enterprises                                   63983 non-null  int32
#  39  NAICS_Manufacturing                                                             63983 non-null  int32
#  40  NAICS_Mining,_quarrying,_and_oil_and_gas_extraction                             63983 non-null  int32
#  41  NAICS_Other_services_(except_public_administration)                             63983 non-null  int32
#  42  NAICS_Professional,_scientific,_and_technical_services                          63983 non-null  int32
#  43  NAICS_Public_administration                                                     63983 non-null  int32
#  44  NAICS_Real_estate_and_rental_and_leasing                                        63983 non-null  int32
#  45  NAICS_Retail_trade                                                              63983 non-null  int32
#  46  NAICS_Transportation_and_warehousing                                            63983 non-null  int32
#  47  NAICS_Utilities                                                                 63983 non-null  int32
#  48  NAICS_Wholesale_trade                                                           63983 non-null  int32
#  49  Purpose_of_credit_Business_Expansion_&_Growth                                   63983 non-null  int32
#  50  Purpose_of_credit_Contract_Fulfillment                                          63983 non-null  int32
#  51  Purpose_of_credit_Emergency_&_Unforeseen_Expenses                               63983 non-null  int32
#  52  Purpose_of_credit_Equipment_&_Technology_Upgrades                               63983 non-null  int32
#  53  Purpose_of_credit_Hiring_&_Payroll_Support                                      63983 non-null  int32
#  54  Purpose_of_credit_Inventory_&_Supply_Purchases                                  63983 non-null  int32
#  55  Purpose_of_credit_Marketing_&_Advertising                                       63983 non-null  int32
#  56  Purpose_of_credit_Working_Capital_&_Cash_Flow_Management                        63983 non-null  int32
# dtypes: float64(8), int32(28), int64(18), object(3)
# memory usage: 21.5+ MB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest


#Before we run the supervised models lets use unsupervised learning
# Select numerical columns (since dataset is already cleaned)
df_copy = df_clean
num_cols = df_copy.select_dtypes(include=["int64", "float64"]).columns.tolist()

# Standardizing the dataset
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_copy[num_cols])  # Ensure df_scaled is a NumPy array

inertia = []
k_range = range(2, 10)  # Try k from 2 to 10

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)

# Plot Elbow Curve
plt.figure(figsize=(8, 5))
plt.plot(k_range, inertia, marker="o")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.savefig("images/Elbow_method_for_optimalK.png", dpi=300)
plt.show()

# Optimal k (update this based on the elbow method)
optimal_k = 4  

# Run K-Means
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
df_copy["Cluster"] = kmeans.fit_predict(df_scaled)  # Ensure the column is assigned

# Check if clustering was applied correctly
print(df_copy["Cluster"].value_counts())  # Should show counts for each cluster

# Visualize clusters (using first two PCA components)
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
df_pca = pca.fit_transform(df_scaled)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=df_pca[:, 0], y=df_pca[:, 1], hue=df_copy["Cluster"], palette="viridis")
plt.title("Clusters in PCA-Reduced Space")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.savefig("images/cluster_in_pca_reduced_space.png", dpi=300)
plt.show()

#Check if fraud cases (column: Fraud/Shell_company_Fraud) are more frequent in a specific cluster.
fraud_counts = df_copy.groupby("Cluster")["Fraud/Shell_company_Fraud"].sum()
print(fraud_counts)

#Compare mean values of key financial variables (e.g., Annual_Revenue, Credit_Score) per cluster.
cluster_summary = df_copy.groupby("Cluster")[["Annual_Revenue", "Credit_Score", "Outstanding_loans",'DisbursementGross', 'Zip','State','Term','NoEmp']].mean()
print(cluster_summary)
# Out:
# Cluster
# 0    34490
# 1    17650
# 3     9289
# 2     2554
# Name: count, dtype: int64
# Cluster
# 0    8594.0
# 1    1871.0
# 2     303.0
# 3    2397.0
# Name: Fraud/Shell_company_Fraud, dtype: float64
#          Annual_Revenue  Credit_Score  Outstanding_loans  DisbursementGross  \
# Cluster
# 0          5.201764e+05    599.497275           5.525167          11.236041
# 1          2.026012e+06    600.580850           6.578187          12.725785
# 2          5.114553e+05    287.801096          90.031715          11.313751
# 3          9.202623e+05    600.805684           5.708257          11.585264
#
#                Zip     State       Term      NoEmp
# Cluster
# 0        18.335170  0.394227  63.458133  18.102059
# 1        19.130595  0.393006  98.208839  22.847932
# 2        14.586922  0.393890  79.685200  17.333986
# 3        15.648832  0.394037  78.671870  17.669179

# %%
#Splitting data into training and test data

X = df_clean.select_dtypes(include=['int','float'])
X = X.drop(['Fraud/Shell_company_Fraud'], axis=1)

y = df_clean['Fraud/Shell_company_Fraud']  # Target variable (price)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63983 entries, 0 to 99996
# Data columns (total 54 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   State                                                                           63983 non-null  float64
#  1   Zip                                                                             63983 non-null  int64
#  2   BankState                                                                       63983 non-null  float64
#  3   Term                                                                            63983 non-null  int64
#  4   NoEmp                                                                           63983 non-null  int64
#  5   NewExist                                                                        63983 non-null  float64
#  6   CreateJob                                                                       63983 non-null  int64
#  7   RetainedJob                                                                     63983 non-null  int64
#  8   FranchiseCode                                                                   63983 non-null  int64
#  9   UrbanRural                                                                      63983 non-null  int64
#  10  LowDoc                                                                          63983 non-null  int64
#  11  DisbursementGross                                                               63983 non-null  float64
#  12  Loan_backed_Realestate                                                          63983 non-null  int64
#  13  NumOfapplications                                                               63983 non-null  int64
#  14  payment_consistency                                                             63983 non-null  int64
#  15  Credit_Utilizations                                                             63983 non-null  int64
#  16  Late_Payment                                                                    63983 non-null  int64
#  17  Annual_Revenue                                                                  63983 non-null  float64
#  18  Net_income                                                                      63983 non-null  float64
#  19  Credit_Score                                                                    63983 non-null  int64
#  20  Taxed_filed                                                                     63983 non-null  int64
#  21  Business_Licenses_Status                                                        63983 non-null  int64
#  22  Outstanding_loans                                                               63983 non-null  float64
#  23  fraud_incident                                                                  63983 non-null  int64
#  24  RevLinCr                                                                        63983 non-null  int64
#  25  NAICS_Accommodation_and_food_services                                           63983 non-null  int32
#  26  NAICS_Administrative_and_support_and_waste_management_and_remediation_services  63983 non-null  int32
#  27  NAICS_Agriculture,_forestry,_fishing_and_hunting                                63983 non-null  int32
#  28  NAICS_Arts,_entertainment,_and_recreation                                       63983 non-null  int32
#  29  NAICS_Construction                                                              63983 non-null  int32
#  30  NAICS_Educational_services                                                      63983 non-null  int32
#  31  NAICS_Finance_and_insurance                                                     63983 non-null  int32
#  32  NAICS_Health_care_and_social_assistance                                         63983 non-null  int32
#  33  NAICS_Information                                                               63983 non-null  int32
#  34  NAICS_Management_of_companies_and_enterprises                                   63983 non-null  int32
#  35  NAICS_Manufacturing                                                             63983 non-null  int32
#  36  NAICS_Mining,_quarrying,_and_oil_and_gas_extraction                             63983 non-null  int32
#  37  NAICS_Other_services_(except_public_administration)                             63983 non-null  int32
#  38  NAICS_Professional,_scientific,_and_technical_services                          63983 non-null  int32
#  39  NAICS_Public_administration                                                     63983 non-null  int32
#  40  NAICS_Real_estate_and_rental_and_leasing                                        63983 non-null  int32
#  41  NAICS_Retail_trade                                                              63983 non-null  int32
#  42  NAICS_Transportation_and_warehousing                                            63983 non-null  int32
#  43  NAICS_Utilities                                                                 63983 non-null  int32
#  44  NAICS_Wholesale_trade                                                           63983 non-null  int32
#  45  Purpose_of_credit_Business_Expansion_&_Growth                                   63983 non-null  int32
#  46  Purpose_of_credit_Contract_Fulfillment                                          63983 non-null  int32
#  47  Purpose_of_credit_Emergency_&_Unforeseen_Expenses                               63983 non-null  int32
#  48  Purpose_of_credit_Equipment_&_Technology_Upgrades                               63983 non-null  int32
#  49  Purpose_of_credit_Hiring_&_Payroll_Support                                      63983 non-null  int32
#  50  Purpose_of_credit_Inventory_&_Supply_Purchases                                  63983 non-null  int32
#  51  Purpose_of_credit_Marketing_&_Advertising                                       63983 non-null  int32
#  52  Purpose_of_credit_Working_Capital_&_Cash_Flow_Management                        63983 non-null  int32
#  53  Cluster                                                                         63983 non-null  int32
# dtypes: float64(7), int32(29), int64(18)
# memory usage: 19.8 MB

# %%
##Lets create metrics List for all the models
metrics_data = []

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
import time

# Ensure X_train, X_test, y_train, y_test are properly defined
# Initialize Dummy Classifier with the desired strategy
dummy_clf = DummyClassifier(strategy='stratified') 

#dummy_clf = RandomForestClassifier()
# Measure execution time
basic_start_time = time.time()
dummy_clf.fit(X_train, y_train)
basic_end_time = time.time()

# Predictions
basic_train_preds = dummy_clf.predict(X_train) 
basic_test_preds = dummy_clf.predict(X_test)

# Calculate execution time
basic_execution_time = basic_end_time - basic_start_time
#Analyze the relationship between the features and the target variables
#To find the correlation between number features we can also change the categorical data of house, default and loan to integer


# Evaluate and print metrics
print(f"Accuracy for train baseline classifier: {dummy_clf.score(X_train, y_train):.4f}")
print(f"Accuracy for test baseline classifier: {dummy_clf.score(X_test, y_test):.4f}")

print(f"Train Precision for Dummy Classifier: {precision_score(y_train, basic_train_preds, average='binary'):.4f}")
print(f"Test Precision for Dummy Classifier: {precision_score(y_test, basic_test_preds, average='binary'):.4f}")

print(f"Train Recall for Dummy Classifier: {recall_score(y_train, basic_train_preds, average='binary'):.4f}")
print(f"Test Recall for Dummy Classifier: {recall_score(y_test, basic_test_preds, average='binary'):.4f}")

print(f"Train F1-Score for Dummy Classifier: {f1_score(y_train, basic_train_preds, average='binary'):.4f}")
print(f"Test F1-Score for Dummy Classifier: {f1_score(y_test, basic_test_preds, average='binary'):.4f}")

metrics_data.append({
    "model_name": "DummyClassifier(baseline)",
    "execution_time": basic_execution_time,
    "train_accuracy": dummy_clf.score(X_train, y_train),
    "train_precision": precision_score(y_train, basic_train_preds, average='binary'),
    "train_recall": recall_score(y_train, basic_train_preds, average='binary'),
    "train_f1_score": f1_score(y_train, basic_train_preds, average='binary'),
    "test_accuracy": dummy_clf.score(X_test, y_test),
    "test_precision": precision_score(y_test, basic_test_preds, average='binary'),
    "test_recall": recall_score(y_test, basic_test_preds, average='binary'),
    "test_f1_score": f1_score(y_test, basic_test_preds, average='binary')
})
# Out:
# Accuracy for train baseline classifier: 0.6753
# Accuracy for test baseline classifier: 0.6741
# Train Precision for Dummy Classifier: 0.2010
# Test Precision for Dummy Classifier: 0.2020
# Train Recall for Dummy Classifier: 0.2023
# Test Recall for Dummy Classifier: 0.2043
# Train F1-Score for Dummy Classifier: 0.2017
# Test F1-Score for Dummy Classifier: 0.2031

# %%
print(df_clean.isnull().mean() * 100)
# Out:
# State                                                                             0.0
# Zip                                                                               0.0
# BankState                                                                         0.0
# NAICS                                                                             0.0
# Term                                                                              0.0
# NoEmp                                                                             0.0
# NewExist                                                                          0.0
# CreateJob                                                                         0.0
# RetainedJob                                                                       0.0
# FranchiseCode                                                                     0.0
# UrbanRural                                                                        0.0
# RevLineCr                                                                         0.0
# LowDoc                                                                            0.0
# DisbursementGross                                                                 0.0
# Fraud/Shell_company_Fraud                                                         0.0
# Loan_backed_Realestate                                                            0.0
# NumOfapplications                                                                 0.0
# payment_consistency                                                               0.0
# Credit_Utilizations                                                               0.0
# Late_Payment                                                                      0.0
# Annual_Revenue                                                                    0.0
# Net_income                                                                        0.0
# Credit_Score                                                                      0.0
# Taxed_filed                                                                       0.0
# Business_Licenses_Status                                                          0.0
# Outstanding_loans                                                                 0.0
# fraud_incident                                                                    0.0
# Purpose_of_credit                                                                 0.0
# RevLinCr                                                                          0.0
# NAICS_Accommodation_and_food_services                                             0.0
# NAICS_Administrative_and_support_and_waste_management_and_remediation_services    0.0
# NAICS_Agriculture,_forestry,_fishing_and_hunting                                  0.0
# NAICS_Arts,_entertainment,_and_recreation                                         0.0
# NAICS_Construction                                                                0.0
# NAICS_Educational_services                                                        0.0
# NAICS_Finance_and_insurance                                                       0.0
# NAICS_Health_care_and_social_assistance                                           0.0
# NAICS_Information                                                                 0.0
# NAICS_Management_of_companies_and_enterprises                                     0.0
# NAICS_Manufacturing                                                               0.0
# NAICS_Mining,_quarrying,_and_oil_and_gas_extraction                               0.0
# NAICS_Other_services_(except_public_administration)                               0.0
# NAICS_Professional,_scientific,_and_technical_services                            0.0
# NAICS_Public_administration                                                       0.0
# NAICS_Real_estate_and_rental_and_leasing                                          0.0
# NAICS_Retail_trade                                                                0.0
# NAICS_Transportation_and_warehousing                                              0.0
# NAICS_Utilities                                                                   0.0
# NAICS_Wholesale_trade                                                             0.0
# Purpose_of_credit_Business_Expansion_&_Growth                                     0.0
# Purpose_of_credit_Contract_Fulfillment                                            0.0
# Purpose_of_credit_Emergency_&_Unforeseen_Expenses                                 0.0
# Purpose_of_credit_Equipment_&_Technology_Upgrades                                 0.0
# Purpose_of_credit_Hiring_&_Payroll_Support                                        0.0
# Purpose_of_credit_Inventory_&_Supply_Purchases                                    0.0
# Purpose_of_credit_Marketing_&_Advertising                                         0.0
# Purpose_of_credit_Working_Capital_&_Cash_Flow_Management                          0.0
# Cluster                                                                           0.0
# dtype: float64

# %%
df_clean.shape
# Out:
# (63983, 58)

# %%
#

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
from sklearn.utils import resample

start_time = time.time()
#X_train_sample, y_train_sample = resample(X_train, y_train, n_samples=25000, random_state=42)  # Adjust sample size
svc_clf = LinearSVC(class_weight='balanced', random_state=42, dual=False).fit(X_train, y_train)
#svc_clf = SVC(kernel='linear', class_weight='balanced', random_state=42).fit(X_train_sample, y_train_sample)
end_time= time.time()

svc_pred_train = svc_clf.predict(X_train)
svc_pred_test = svc_clf.predict(X_test)

print(f"Accuracy for baseline SVC Train {svc_clf.score(X_train,y_train)}")
print(f"Accuracy for baseline SVC Test {svc_clf.score(X_test,y_test)}")

print(f"Train Precision for SVC Classifier: {precision_score(y_train, svc_pred_train, average='binary'):.4f}")
print(f"Test Precision for SVC Classifier: {precision_score(y_test, svc_pred_test, average='binary'):.4f}")

print(f"Train Recall for SVC Classifier: {recall_score(y_train, svc_pred_train, average='binary'):.4f}")
print(f"Test Recall for SVC Classifier: {recall_score(y_test, svc_pred_test, average='binary'):.4f}")

print(f"Train F1-Score for SVC Classifier: {f1_score(y_train, svc_pred_train, average='binary'):.4f}")
print(f"Test F1-Score for SVC Classifier: {f1_score(y_test, svc_pred_test, average='binary'):.4f}")

metrics_data.append({
    "model_name": "SVC(baseline)",
    "execution_time": end_time - start_time,
    "train_accuracy": svc_clf.score(X_train,y_train),
    "train_precision": precision_score(y_train, svc_pred_train, average='binary'),
    "train_recall": recall_score(y_train, svc_pred_train, average='binary'),
    "train_f1_score": f1_score(y_train, svc_pred_train, average='binary'),
    "test_accuracy": svc_clf.score(X_test,y_test),
    "test_precision": precision_score(y_test, svc_pred_test, average='binary'),
    "test_recall": recall_score(y_test, svc_pred_test, average='binary'),
    "test_f1_score": f1_score(y_test, 
                              svc_pred_test, average='binary')
})
# Out:
# Accuracy for baseline SVC Train 0.7139452193959286
# Accuracy for baseline SVC Test 0.7128233179651481
# Train Precision for SVC Classifier: 0.3905
# Test Precision for SVC Classifier: 0.3892
# Train Recall for SVC Classifier: 0.6961
# Test Recall for SVC Classifier: 0.6950
# Train F1-Score for SVC Classifier: 0.5003
# Test F1-Score for SVC Classifier: 0.4990

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import time

lg_start_time = time.time()
scaler = StandardScaler() 
X_train_scaled = scaler.fit_transform(X_train) 
X_test_scaled = scaler.transform(X_test)

log_reg = LogisticRegression(max_iter=1000, random_state=42) 
#log_reg = LogisticRegression(n_estimators=100, random_state=42)
log_reg.fit(X_train_scaled, y_train)

lg_end_time = time.time()
log_reg_train_preds = log_reg.predict(X_train_scaled) 
log_reg_test_preds = log_reg.predict(X_test_scaled)

log_reg_train_accuracy = accuracy_score(y_train, log_reg_train_preds) 
log_reg_train_precision = precision_score(y_train, log_reg_train_preds) 
log_reg_train_recall = recall_score(y_train, log_reg_train_preds) 
log_reg_train_f1 = f1_score(y_train, log_reg_train_preds)

log_reg_test_accuracy = accuracy_score(y_test, log_reg_test_preds) 
log_reg_test_precision = precision_score(y_test, log_reg_test_preds) 
log_reg_test_recall = recall_score(y_test, log_reg_test_preds) 
log_reg_test_f1 = f1_score(y_test, log_reg_test_preds)

execution_time_lg =  lg_end_time -lg_start_time 
print(f"Total execution time: {execution_time_lg:.2f} seconds")
print(f"Logistic Regression Train Accuracy: {log_reg_train_accuracy:.4f}") 
print(f"Logistic Regression Test Accuracy: {log_reg_test_accuracy:.4f}")

print(f"Train Precision for Logictics Regression: {log_reg_train_precision}") 
print(f"Test Precision for Logictics Regression: {log_reg_test_precision}")

print(f"TrainRecall for Logictics Regression: {log_reg_train_recall}") 
print(f"Test Recall for Logictics Regression: {log_reg_test_recall}")

print(f"Train F1-Score for Logictics Regression: {log_reg_train_f1}") 
print(f"Test F1-Score for Logictics Regression: {log_reg_test_f1}")

print("\nClassification Report:") 
print(classification_report(y_test, log_reg_test_preds))

metrics_data.append({
    "model_name": "LogisticRegression(default)",
    "execution_time": execution_time_lg,
    "train_accuracy": log_reg_train_accuracy,
    "train_precision": log_reg_train_precision,
    "train_recall": log_reg_train_recall ,
    "train_f1_score": log_reg_train_f1 ,
    "test_accuracy": log_reg_test_accuracy,
    "test_precision": log_reg_test_precision,
    "test_recall": log_reg_test_recall,
    "test_f1_score": log_reg_test_f1
})
# Out:
# Total execution time: 0.25 seconds
# Logistic Regression Train Accuracy: 0.7992
# Logistic Regression Test Accuracy: 0.7970
# Train Precision for Logictics Regression: 0.5290858725761773
# Test Precision for Logictics Regression: 0.5161290322580645
# TrainRecall for Logictics Regression: 0.2176224838587163
# Test Recall for Logictics Regression: 0.21268515001898974
# Train F1-Score for Logictics Regression: 0.3083961248654467
# Test F1-Score for Logictics Regression: 0.3012372243141474
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.95      0.88     10164
#          1.0       0.52      0.21      0.30      2633
#
#     accuracy                           0.80     12797
#    macro avg       0.67      0.58      0.59     12797
# weighted avg       0.76      0.80      0.76     12797

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

#ecisionTree (default)	DecisionTreeClassifier(max_depth=1, criterion='gini')
#KNN	KNeighborsClassifier(n_neighbors=5, weights='uniform', metric='minkowski')
#SVM	SVC(C=1.0, kernel='rbf', gamma='scale', probability=True)

models = {
    'DecisionTree(Default)': {
        'model': DecisionTreeClassifier(random_state=42)
    },
    'KNeighbors(Default)': {
        'model': KNeighborsClassifier(n_neighbors=5)
    },
    'SVM(Default)': {
        'model': SVC(random_state=42)
  }
}


print(f" Model	                           |            Train Time	        |           Train Accuracy	        |        Test Accuracy       |")
print(f" Logistic Regression	           |     {execution_time_lg}        |        {log_reg_train_accuracy}	|  {log_reg_test_accuracy}   |")

#X = df_clean.select_dtypes(include=['int','float'])
#X = X.drop(['y_numeric'], axis=1)

#y = df_clean['y_numeric']  # Target variable (price)

# Split data into train and test sets
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

for model_name, model_details in models.items():
    print(f"\nRunning GridSearchCV for {model_name}, {model_details}...")

    start_time = time.time()

    # Initialize AdaBoost with the selected model as the base estimator
    # ada_boost = AdaBoostClassifier(estimator=model_details['model'], n_estimators=50, random_state=42)

     # Create a pipeline with scaling and AdaBoost model
    pipeline = Pipeline([
        ('scaler', StandardScaler(with_mean=False)),  # Apply scaling
        ('model', model_details['model'])  # Add the model dynamically
    ])

    # Grid Search with 5-fold cross-validation (this time no need for param_grid as base_estimator is set)
    grid = GridSearchCV(
        pipeline, 
        param_grid={},  # You can specify other hyperparameters here for the AdaBoost or base estimator
        cv=5, 
        scoring='roc_auc', 
        verbose=0
    )

    # Fit the grid search
    grid.fit(X_train, y_train)

    # Best parameters and model performance
    #print(f"Best Parameters for {model_name}: {grid_log_reg.best_params_}")
    #print(f"Best Cross-Validation Accuracy for {model_name}: {grid_log_reg.best_score_}")
    
    # Evaluate the best model on the test set
    #best_model = grid_log_reg.best_estimator_
    #y_pred = best_model.predict(X_test)

    end_time = time.time()
    train_preds = grid.predict(X_train) 
    test_preds = grid.predict(X_test)

    train_accuracy = accuracy_score(y_train, train_preds) 
    train_precision = precision_score(y_train, train_preds) 
    train_recall = recall_score(y_train, train_preds) 
    train_f1 = f1_score(y_train, train_preds)

    test_accuracy = accuracy_score(y_test, test_preds) 
    test_precision = precision_score(y_test, test_preds) 
    test_recall = recall_score(y_test, test_preds) 
    test_f1 = f1_score(y_test, test_preds)

    execution_time =  end_time - start_time 
    print(f" model - {model_name}")
    print(f" execution time - {execution_time}")
    print(f" accuracy train - {train_accuracy} , accuracy test -  {test_accuracy}")
    print(f" precision train - {train_precision} , precision test -  {test_precision}")
    print(f" recall train - {train_recall} , recall test -  {test_recall}")
    print(f" F1-score train - {train_f1} ,  F1-score test -  {test_f1}")
    
    metrics_data.append({
    "model_name": model_name,
    "execution_time": execution_time,
    "train_accuracy": train_accuracy,
    "train_precision": train_precision,
    "train_recall": train_recall ,
    "train_f1_score": train_f1 ,
    "test_accuracy": test_accuracy,
    "test_precision": test_precision,
    "test_recall": test_recall,
    "test_f1_score": test_f1
})
# Out:
#  Model	                           |            Train Time	        |           Train Accuracy	        |        Test Accuracy       |
#  Logistic Regression	           |     0.24901485443115234        |        0.7991638338608213	|  0.7969836680471986   |
#
# Running GridSearchCV for DecisionTree(Default), {'model': DecisionTreeClassifier(random_state=42)}...
#  model - DecisionTree(Default)
#  execution time - 4.502729415893555
#  accuracy train - 1.0 , accuracy test -  0.8787215753692271
#  precision train - 1.0 , precision test -  0.7010040907400521
#  recall train - 1.0 , recall test -  0.7159134067603494
#  F1-score train - 1.0 ,  F1-score test -  0.708380308154829
#
# Running GridSearchCV for KNeighbors(Default), {'model': KNeighborsClassifier()}...
#  model - KNeighbors(Default)
#  execution time - 3.3909990787506104
#  accuracy train - 0.8508185832063455 , accuracy test -  0.7877627568961475
#  precision train - 0.7289690069576218 , precision test -  0.4727511490479317
#  recall train - 0.43771363463729585 , recall test -  0.2734523357387011
#  F1-score train - 0.5469862363550071 ,  F1-score test -  0.34648700673724736
#
# Running GridSearchCV for SVM(Default), {'model': SVC(random_state=42)}...
#  model - SVM(Default)
#  execution time - 608.3121154308319
#  accuracy train - 0.7942406126675263 , accuracy test -  0.794248652027819
#  precision train - 0.5 , precision test -  0.0
#  recall train - 9.494872768704899e-05 , recall test -  0.0
#  F1-score train - 0.00018986140117714068 ,  F1-score test -  0.0
# C:\Users\suchi\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Set plot style
df_metrics = pd.DataFrame(metrics_data)
sns.set(style="whitegrid")

# Reshape the data for plotting (melt the DataFrame)
df_melted = df_metrics.melt(id_vars=["model_name"], 
                            value_vars=["train_accuracy", "train_precision", "train_recall", "train_f1_score", 
                                        "test_accuracy", "test_precision", "test_recall", "test_f1_score"],
                            var_name="metric", value_name="score")

# Create a combined plot for overall metrics based on the models
plt.figure(figsize=(12, 8))
sns.barplot(x="model_name", y="score", hue="metric", data=df_melted, palette="Set2")

# Customize the plot
plt.title("Overall Metrics Comparison Based on Simple base Models")
plt.ylabel("Score")
plt.xlabel("Model Name")
plt.xticks(rotation=90)
plt.legend(title="Metrics", loc='upper left', bbox_to_anchor=(1, 1))
plt.savefig("images/barplot_for_overall_basemodel_metrics.png", dpi=300)
# Display the plot
plt.tight_layout()
plt.show()
